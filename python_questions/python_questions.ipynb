# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# 1.  Select all the data from table `house_price_data` to check if the data was imported correctly.

# %%
house_price_data = pd.read_excel('regression_data.xls')
house_price_data.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0             0    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2             0    98028  47.7379 -122.233           2720        8062  180000
# 3             0    98136  47.5208 -122.393           1360        5000  604000
# 4             0    98074  47.6168 -122.045           1800        7503  510000
#
# [5 rows x 21 columns]

# %% [markdown]
# 2.  Drop the column `date` from the data frame, as we would not use it in the analysis. Select all the data from the table to verify if the command worked. Limit your returned results to 10.

# %%
house_price_data.drop('date',axis=1,inplace=True)
house_price_data.head(10)
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
# 5  7237550310         4       4.50         5420    101930     1.0           0
# 6  1321400060         3       2.25         1715      6819     2.0           0
# 7  2008000270         3       1.50         1060      9711     1.0           0
# 8  2414600126         3       1.00         1780      7470     1.0           0
# 9  3793500160         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
# 5     0          3     11        3890           1530      2001             0
# 6     0          3      7        1715              0      1995             0
# 7     0          3      7        1060              0      1963             0
# 8     0          3      7        1050            730      1960             0
# 9     0          3      7        1890              0      2003             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15    price
# 0    98178  47.5112 -122.257           1340        5650   221900
# 1    98125  47.7210 -122.319           1690        7639   538000
# 2    98028  47.7379 -122.233           2720        8062   180000
# 3    98136  47.5208 -122.393           1360        5000   604000
# 4    98074  47.6168 -122.045           1800        7503   510000
# 5    98053  47.6561 -122.005           4760      101930  1230000
# 6    98003  47.3097 -122.327           2238        6819   257500
# 7    98198  47.4095 -122.315           1650        9711   291850
# 8    98146  47.5123 -122.337           1780        8113   229500
# 9    98038  47.3684 -122.031           2390        7570   323000

# %% [markdown]
# 3.  How many rows of data do you have?

# %%
house_price_data.shape[0]
# Out:
# 21597

# %% [markdown]
# 4.  Find the unique values of the following columns:
#
#     - What are the unique values in the column `bedrooms`?
#     - What are the unique values in the column `bathrooms`?
#     - What are the unique values in the column `floors`?
#     - What are the unique values in the column `condition`?
#     - What are the unique values in the column `grade`?

# %%
house_price_data['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  8,  9, 11, 10, 33])

# %%
house_price_data['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 0.5 , 5.5 ,
#        6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
house_price_data['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
house_price_data['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2])

# %%
house_price_data['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13])

# %% [markdown]
# 5.  Arrange the data in decreasing order by the price of the house. Return only the IDs of the top 10 most expensive houses in your data.

# %%
house_price_data.sort_values(by= 'price', ascending = False).head(10)['id']
# Out:
# 7245    6762700020
# 3910    9808700762
# 9245    9208900037
# 4407    2470100110
# 1446    8907500070
# 1313    7558700030
# 1162    1247600105
# 8085    1924059029
# 2624    7738500731
# 8629    3835500195
# Name: id, dtype: int64

# %% [markdown]
# 6.  What is the average price of all the properties in your data?

# %%
media = house_price_data['price'].mean()
print("La media es: ", media)
# Out:
# La media es:  540296.5735055795

# %% [markdown]
# 7. In this exercise use a simple `groupby` to check the properties of some of the categorical variables in our data
#
#     - What is the average price of the houses grouped by bedrooms? The returned result should have only two columns: `Bedrooms` and `Average price`.
#     - What is the average `sqft_living` of the houses grouped by bedrooms? The returned result should have only two columns, `Bedrooms` and `Average_sqft_living`.
#     - What is the average price of the houses with a waterfront and without a waterfront? The returned result should have only two columns, `Waterfront` and `Average_price`.
#     - Is there any correlation between the columns `condition` and `grade`? Also, create a plot to visually check if there is a positive correlation or negative correlation or no correlation between both variables.
#
#     - Get the number of houses in each category (ie number of houses for a given `condition`) to assess if that category is well represented in the dataset to include it in your analysis. For eg. If the category is under-represented as compared to other categories, ignore that category in this analysis

# %%
#Primer apartado
house_price_data.groupby('bedrooms')['price'].mean()
# Out:
# bedrooms
# 1     3.182395e+05
# 2     4.013877e+05
# 3     4.662766e+05
# 4     6.355647e+05
# 5     7.868741e+05
# 6     8.258535e+05
# 7     9.514478e+05
# 8     1.105077e+06
# 9     8.939998e+05
# 10    8.200000e+05
# 11    5.200000e+05
# 33    6.400000e+05
# Name: price, dtype: float64

# %%
#Segundo apartado
house_price_data.groupby('bedrooms')['sqft_living'].mean()
# Out:
# bedrooms
# 1      888.153061
# 2     1239.752899
# 3     1805.837235
# 4     2554.649666
# 5     3047.545284
# 6     3284.341912
# 7     3974.210526
# 8     3800.000000
# 9     3775.000000
# 10    3706.666667
# 11    3000.000000
# 33    1620.000000
# Name: sqft_living, dtype: float64

# %%
#Tercer apartado
house_price_data.groupby('waterfront')['price'].mean()
# Out:
# waterfront
# 0    5.317623e+05
# 1    1.662524e+06
# Name: price, dtype: float64

# %%
#Cuarto apartado
sns.regplot(x = 'condition', y = 'grade', data= house_price_data)
# Out:
# <AxesSubplot: xlabel='condition', ylabel='grade'>

# %%
#Quinto apartado
#Por condicion
house_price_data['condition'].value_counts()
# Out:
# 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: condition, dtype: int64

# %%
#Por baños
house_price_data['bathrooms'].value_counts()
# Out:
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.25       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
#Por pisos
house_price_data['floors'].value_counts()
# Out:
# 1.0    10673
# 2.0     8235
# 1.5     1910
# 3.0      611
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64

# %%
#Por calificacion
house_price_data['grade'].value_counts()
# Out:
# 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %%
#Por precio
house_price_data['price'].value_counts()
# Out:
# 450000    172
# 350000    172
# 550000    159
# 500000    152
# 425000    150
#          ...
# 278800      1
# 439888      1
# 354901      1
# 942000      1
# 402101      1
# Name: price, Length: 3622, dtype: int64

# %% [markdown]
# 8. One of the customers is only interested in the following houses:
#
#     - Number of bedrooms either 3 or 4
#     - Bathrooms more than 3
#     - One Floor
#     - No waterfront
#     - Condition should be 3 at least
#     - Grade should be 5 at least
#     - Price smaller than 300000
#
#     For the rest of the things, they are not too concerned. Write code to find what are the houses available for them?

# %%
house_price_data[((house_price_data['bedrooms']==3) | (house_price_data['bedrooms']==4)) & (house_price_data['bathrooms']>3) & (house_price_data['floors']==1) & (house_price_data['waterfront']==0) & (house_price_data['condition']>=3) & (house_price_data['grade']>=5) & (house_price_data['price']<300000)]
#Por lo que vemos que no hay casas disponibles con estas caracteristicas.
# Out:
# Empty DataFrame
# Columns: [id, date, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, price]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# 9. Your manager wants to find out the list of properties whose prices are twice more than the average of all the properties in the database. Write code to show them the list of such properties.

# %%
house_price_data[house_price_data['price']<media]
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# 6      1321400060 2014-06-27         3       2.25         1715      6819
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0         1.0           0     0          3  ...        1180              0
# 1         2.0           0     0          3  ...        2170            400
# 2         1.0           0     0          3  ...         770              0
# 4         1.0           0     0          3  ...        1680              0
# 6         2.0           0     0          3  ...        1715              0
# ...       ...         ...   ...        ...  ...         ...            ...
# 21592     3.0           0     0          3  ...        1530              0
# 21593     2.0           0     0          3  ...        2310              0
# 21594     2.0           0     0          3  ...        1020              0
# 21595     2.0           0     0          3  ...        1600              0
# 21596     2.0           0     0          3  ...        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 4          1987             0    98074  47.6168 -122.045           1800
# 6          1995             0    98003  47.3097 -122.327           2238
# ...         ...           ...      ...      ...      ...            ...
# 21592      2009             0    98103  47.6993 -122.346           1530
# 21593      2014             0    98146  47.5107 -122.362           1830
# 21594      2009             0    98144  47.5944 -122.299           1020
# 21595      2004             0    98027  47.5345 -122.069           1410
# 21596      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15   price
# 0            5650  221900
# 1            7639  538000
# 2            8062  180000
# 4            7503  510000
# 6            6819  257500
# ...           ...     ...
# 21592        1509  360000
# 21593        7200  400000
# 21594        2007  402101
# 21595        1287  400000
# 21596        1357  325000
#
# [13680 rows x 21 columns]

# %% [markdown]
# 10. Most customers are interested in properties with three or four bedrooms. What is the difference in average prices of the properties with three and four bedrooms? In this case you can simply use a `groupby` to check the prices for those particular houses.

# %%
house_price_data[house_price_data['bedrooms']==4]['price'].mean() - house_price_data[house_price_data['bedrooms']==3]['price'].mean()
# Out:
# 169288.0862289045

# %% [markdown]
# 11. What are the different locations where properties are available in your database? (distinct zip codes).

# %%
house_price_data['zipcode'].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039])

# %% [markdown]
# 12. Show all the properties that were renovated.

# %%
house_price_data[house_price_data['yr_renovated'] > 0]
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 35     9547205180 2014-06-13         3       2.50         2300      3060
# 95     1483300570 2014-09-08         4       2.50         3300     10250
# 103    2450000295 2014-10-07         3       2.50         2920      8113
# 115    3626039325 2014-11-21         3       3.50         4380      6350
# ...           ...        ...       ...        ...          ...       ...
# 19606  7351200295 2015-01-14         3       1.75         1760      6788
# 20041   126039256 2014-09-04         3       2.00         1520      5040
# 20428  4305600360 2015-02-25         4       2.50         2400      9612
# 20431  3319500628 2015-02-12         3       1.50         1010      1546
# 20946  1278000210 2015-03-11         2       1.00          828      4524
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 1         2.0           0     0          3  ...        2170            400
# 35        1.5           0     0          3  ...        1510            790
# 95        1.0           0     0          3  ...        2390            910
# 103       2.0           0     0          3  ...        2920              0
# 115       2.0           0     0          3  ...        2780           1600
# ...       ...         ...   ...        ...  ...         ...            ...
# 19606     2.0           1     4          3  ...        1760              0
# 20041     2.0           0     0          3  ...        1520              0
# 20428     1.0           0     0          3  ...        1230           1170
# 20431     2.0           0     0          3  ...        1010              0
# 20946     1.0           0     0          3  ...         828              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1          1951          1991    98125  47.7210 -122.319           1690
# 35         1930          2002    98115  47.6827 -122.310           1590
# 95         1946          1991    98040  47.5873 -122.249           1950
# 103        1950          2010    98004  47.5814 -122.196           2370
# 115        1900          1999    98117  47.6981 -122.368           1830
# ...         ...           ...      ...      ...      ...            ...
# 19606      1940          1960    98125  47.7336 -122.284           1630
# 20041      1977          2006    98177  47.7770 -122.362           1860
# 20428      1962          2009    98059  47.4799 -122.127           2430
# 20431      1971          2014    98144  47.5998 -122.311           1010
# 20946      1968          2007    98001  47.2655 -122.244            828
#
#        sqft_lot15    price
# 1            7639   538000
# 35           3264   696000
# 95           6045   905000
# 103          8113  1090000
# 115          6350   740500
# ...           ...      ...
# 19606        7588  1150000
# 20041        8710   434900
# 20428        5539   500012
# 20431        1517   356999
# 20946        5402   110000
#
# [914 rows x 21 columns]

# %% [markdown]
# 13. Provide the details of the property that is the 11th most expensive property in your database.

# %%
house_price_data.sort_values(by='price',ascending=False).head(11).iloc[10]
# Out:
# id                        6065300370
# date             2015-05-06 00:00:00
# bedrooms                           5
# bathrooms                        6.0
# sqft_living                     7440
# sqft_lot                       21540
# floors                           2.0
# waterfront                         0
# view                               0
# condition                          3
# grade                             12
# sqft_above                      5550
# sqft_basement                   1890
# yr_built                        2003
# yr_renovated                       0
# zipcode                        98006
# lat                          47.5692
# long                        -122.189
# sqft_living15                   4740
# sqft_lot15                     19329
# price                        4210000
# Name: 12358, dtype: object
